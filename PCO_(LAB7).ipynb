# %% [markdown]
# <a href="https://colab.research.google.com/github/1BM23CS308/1BM23CS308_BIS_LAB/blob/main/PCO_(LAB7).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

L=10;T=5;p=0.4
road=np.random.choice([0,1],size=L,p=[1-p,p])
total_cars=np.sum(road)
print("Initial road:",''.join(map(str,road)))
print("Total cars:",total_cars)
for step in range(T):
    new_road=np.zeros_like(road);moves=0
    for i in range(L):
        if road[i]==1:
            n=(i+1)%L
            if road[n]==0:
                new_road[n]=1;moves+=1
            else:new_road[i]=1
    print(f"Step {step+1:02d}: {''.join(map(str,new_road))} | Cars moved: {moves}")
    road=new_road.copy()
print("Final road:",''.join(map(str,road)))
print("Total cars:",total_cars)
# Out:
# Initial road: 0001000110
# Total cars: 3
# Step 01: 0000100101 | Cars moved: 2
# Step 02: 1000010010 | Cars moved: 3
# Step 03: 0100001001 | Cars moved: 3
# Step 04: 1010000100 | Cars moved: 3
# Step 05: 0101000010 | Cars moved: 3
# Final road: 0101000010
# Total cars: 3
